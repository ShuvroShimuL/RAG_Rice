# %% [markdown]
# ## Rice Advisory RAG System - Development Notebook
#
# This notebook is for developing and testing the RAG system components.

# %%
import os
import sys

# Add src directory to Python path
sys.path.append(os.path.abspath("../src"))
